# %%
                                # Name-: Rohit Bhardwaj                               
                                 # Batch-: Data science Master
                                 # Asssignment :- Statistics Advance_5




# Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5 using Python. Interpret the results.



import scipy.stats as stats

# Sample statistics
sample_mean = 50
sample_stddev = 5
sample_size = 100  # You need to provide the sample size

# Confidence level (95%)
confidence_level = 0.95

# Calculate the standard error of the mean (SEM)
sem = sample_stddev / (sample_size ** 0.5)

# Calculate the margin of error (MOE) using the t-distribution
t_score = stats.t.ppf((1 + confidence_level) / 2, df=sample_size - 1)
margin_of_error = t_score * sem

# Calculate the confidence interval
lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

# Interpretation
print(f"Sample Mean: {sample_mean}")
print(f"95% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

# Interpretation
print("We are 95% confident that the true population mean is between", round(lower_bound, 2), "and", round(upper_bound, 2))

# %%
# Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
# matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
# brown. Use Python to perform the test with a significance level of 0.05.

import numpy as np
import scipy.stats as stat

# observed frequency of colour i the sample
observed_data = np.array([35,25,20,10,15,20])

expected_data = np.array([0.20,0.20,0.20,0.10,0.10,0.20]) *np.sum(observed_data)

chi_square_statistics,p_value = stat.chisquare(observed_data,expected_data)

significance_level = 0.05

if p_value < significance_level:
    print('reject null hypothisis')
else:
    print('fail to reject null hypothisis')


print(p_value,chi_square_statistics)
# Out:
# fail to reject null hypothisis
# 0.22064030793671066 7.0

# %%
# Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following
# data:
    
# Outcome1 20 15
# Outcome2 10 25
# Outcome3 15 20
# Interpret the results of the test.



import scipy.stats as stat

observed_data1 = [[20,10],
                 [10,25],
                 [15,20]]


chi_square_statistic1,p_value1, _, _  = stat.chi2_contingency(observed_data1)

print(chi_square_statistic1,p_value1)
# Out:
# 9.571909571909574 0.008346151154589544

# %%
# Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
# smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
# population who smoke.

import scipy.stats as stats

# Sample size
sample_size = 500

# Number of individuals who smoke
smokers = 60

# Calculate the proportion of smokers
smoking_proportion = smokers / sample_size

# Confidence level
confidence_level = 0.95

# Calculate the standard error
standard_error = (smoking_proportion * (1 - smoking_proportion) / sample_size) ** 0.5

# Calculate the margin of error
margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * standard_error

# Calculate the confidence interval
lower_bound = smoking_proportion - margin_of_error
upper_bound = smoking_proportion + margin_of_error

# Print the results
print(f"95% Confidence Interval for Smoking Proportion: ({lower_bound:.4f}, {upper_bound:.4f})")
# Out:
# 95% Confidence Interval for Smoking Proportion: (0.0915, 0.1485)

# %%
# Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
# of 12 using Python. Interpret the results.

import scipy.stats as stats

sample_mean = 75
sample_std_dev= 12
sample_size = 100

confidence_level = 0.90

margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std_dev / (sample_size**0.5))

lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_erro
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 15
#      12 margin_of_error = stats.norm.ppf((1 + confidence_level) / 2) * (sample_std_dev / (sample_size**0.5))
#      14 lower_bound = sample_mean - margin_of_error
# ---> 15 upper_bound = sample_mean + margin_of_erro
#
# NameError: name 'margin_of_erro' is not defined

# %%
# Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
# area corresponding to a chi-square statistic of 15.


import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stat

df = 10

x = np.linspace(0,30,1000)
# print(x)

pdf = stat.chi2.pdf(x,df)
# print(pdf)

# creaat plot

plt.figure(figsize=(8,6))

plt.plot(x,pdf,color = 'r')
plt.fill_between(x, pdf, where=(x >= 15), color='red', alpha=0.5, label="Area for Chi-square < 15")
plt.axvline(x=15, color='g', linestyle='--', label="Chi-square = 15")

# Label the axes and add a legend
plt.xlabel("Chi-square Value")
plt.ylabel("Probability Density")
plt.legend()

# Show the plot
plt.title("Chi-square Distribution with Shaded Area")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 15, 7, 12, 8]

# Create a basic plot
plt.plot(x, y)

# Draw a horizontal line at y=10
plt.axhline(y=10, color='green', linestyle='--', label='Horizontal Line at y=10')

# Add labels and legend
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()

# Show the plot
plt.show()

# %%
# Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
# preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
# prefer Coke.




import scipy.stats as stats

# Sample size
sample_size = 1000

# Number of people who prefer Coke
preferred_coke = 520

# Calculate the sample proportion
sample_proportion = preferred_coke / sample_size

# Confidence level (e.g., 99%)
confidence_level = 0.99

# Calculate the critical value (Z-score for a 99% confidence level)
critical_value = stats.norm.ppf((1 + confidence_level) / 2)

# Calculate the standard error
standard_error = (sample_proportion * (1 - sample_proportion) / sample_size) ** 0.5

# Calculate the margin of error
margin_of_error = critical_value * standard_error

# Calculate the confidence interval
lower_bound = sample_proportion - margin_of_error
upper_bound = sample_proportion + margin_of_error

# Print the results
print(f"99% Confidence Interval for Proportion Who Prefer Coke: ({lower_bound:.4f}, {upper_bound:.4f})")
# Out:
# 99% Confidence Interval for Proportion Who Prefer Coke: (0.4793, 0.5607)

# %%
# Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
# 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
# expected frequencies of a fair coin. Use a significance level of 0.05.



import scipy.stats as stats

# Observed frequency of tails
observed_tails = 45

# Expected frequency of tails for a fair coin
expected_tails = 50

# Degrees of freedom (number of categories - 1)
df = 1

# Calculate the chi-square statistic
chi_square_statistic = ((observed_tails - expected_tails)**2) / expected_tails

# Set the significance level
alpha = 0.05

# Calculate the p-value
p_value = 1 - stats.chi2.cdf(chi_square_statistic, df)

# Print the results
print(f"Chi-square Statistic: {chi_square_statistic:.4f}")
print(f"P-value: {p_value:.4f}")

# Interpret the results
if p_value < alpha:
    print("Reject the null hypothesis: The coin may be biased towards tails.")
else:
    print("Fail to reject the null hypothesis: The coin does not appear to be biased towards tails.")
# Out:
# Chi-square Statistic: 0.5000
# P-value: 0.4795
# Fail to reject the null hypothesis: The coin does not appear to be biased towards tails.

# %%
9. A study was conducted to determine if there is an association between smoking status (smoker or
non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below.
Conduct a chi-square test for independence to determine if there is a significant association between
smoking status and lung cancer diagnosis.

                     Lung Cancer: Yes        Lung Cancer: No
Smoker                        60                   140
Non-smoker                    30                   170


Use a significance level of 0.05.
